# %%
import pandas as pd
import json

# Sample JSON data
data = '''{
      "listings": [
        {
            "id": "980600",
            "pms": "smartbnb",
            "name": "Luxury Lakefront Family Retreat",
            "no_of_bedrooms": 4,
            "min": 249,
            "base": 451,
            "max": null,
            "group": null,
            "subgroup": null,
            "tags": null,
            "notes": null,
            "isHidden": false,
            "push_enabled": false,
            "last_date_pushed": "2025-01-19T06:11:50.000Z",
            "last_booked_date": "2024-12-19T00:00:00.000Z",
            "occupancy_next_30": "17 %",
            "market_occupancy_next_30": "25 %",
            "occupancy_next_60": "8 %",
            "market_occupancy_next_60": "18 %",
            "occupancy_next_90": "10 %",
            "market_occupancy_next_90": "16 %",
            "occupancy_next_120": "11 %",
            "market_occupancy_next_120": "16 %",
            "revenue_next_120": 0,
            "stly_revenue_next_120": 0,
            "adr_next_120": 0,
            "stly_adr_next_120": 0,
            "recommended_base_price": "Unavailable",
            "last_refreshed_at": null
        },
        {
            "id": "1071904",
            "pms": "smartbnb",
            "name": "Lakefront Family Getaway",
            "no_of_bedrooms": 3,
            "min": 350,
            "base": 470,
            "max": null,
            "group": null,
            "subgroup": null,
            "tags": null,
            "notes": null,
            "isHidden": true,
            "push_enabled": false,
            "last_date_pushed": "2023-06-23T23:55:52.000Z",
            "last_booked_date": "No Booking",
            "occupancy_next_30": null,
            "market_occupancy_next_30": "Unavailable",
            "occupancy_next_60": null,
            "market_occupancy_next_60": "Unavailable",
            "occupancy_next_90": null,
            "market_occupancy_next_90": "Unavailable",
            "occupancy_next_120": null,
            "market_occupancy_next_120": "Unavailable",
            "revenue_next_120": null,
            "stly_revenue_next_120": "Unavailable",
            "adr_next_120": null,
            "stly_adr_next_120": "Unavailable",
            "recommended_base_price": "Unavailable",
            "last_refreshed_at": null
        },
        {
            "id": "1096278",
            "pms": "smartbnb",
            "name": "Lakefront Getaway by Sylvan Bch",
            "no_of_bedrooms": null,
            "min": 180,
            "base": 200,
            "max": 600,
            "group": null,
            "subgroup": null,
            "tags": null,
            "notes": null,
            "isHidden": true,
            "push_enabled": false,
            "last_date_pushed": null,
            "last_booked_date": "2023-06-18T00:00:00.000Z",
            "occupancy_next_30": "0 %",
            "market_occupancy_next_30": "13 %",
            "occupancy_next_60": "0 %",
            "market_occupancy_next_60": "11 %",
            "occupancy_next_90": "0 %",
            "market_occupancy_next_90": "11 %",
            "occupancy_next_120": "0 %",
            "market_occupancy_next_120": "11 %",
            "revenue_next_120": 0,
            "stly_revenue_next_120": "-",
            "adr_next_120": 0,
            "stly_adr_next_120": "-",
            "recommended_base_price": "Unavailable",
            "last_refreshed_at": null
        },
        {
            "id": "1119824",
            "pms": "smartbnb",
            "name": "Lakefront | Kayak| nr Sylvan Bch",
            "no_of_bedrooms": 2,
            "min": 150,
            "base": 250,
            "max": null,
            "group": null,
            "subgroup": null,
            "tags": null,
            "notes": null,
            "isHidden": false,
            "push_enabled": false,
            "last_date_pushed": "2025-01-19T06:11:45.000Z",
            "last_booked_date": "2024-08-27T00:00:00.000Z",
            "occupancy_next_30": "100 %",
            "market_occupancy_next_30": "19 %",
            "occupancy_next_60": "62 %",
            "market_occupancy_next_60": "15 %",
            "occupancy_next_90": "41 %",
            "market_occupancy_next_90": "13 %",
            "occupancy_next_120": "56 %",
            "market_occupancy_next_120": "12 %",
            "revenue_next_120": 1492,
            "stly_revenue_next_120": 6996,
            "adr_next_120": 373,
            "stly_adr_next_120": 175,
            "recommended_base_price": "Unavailable",
            "last_refreshed_at": "2025-02-06T00:04:50+00:00"
        },
        {
            "id": "1121198",
            "pms": "smartbnb",
            "name": "Lakefront Family Getaway",
            "no_of_bedrooms": 3,
            "min": 179,
            "base": 350,
            "max": null,
            "group": null,
            "subgroup": null,
            "tags": null,
            "notes": null,
            "isHidden": false,
            "push_enabled": false,
            "last_date_pushed": "2025-01-19T06:11:45.000Z",
            "last_booked_date": "2024-11-30T00:00:00.000Z",
            "occupancy_next_30": "3 %",
            "market_occupancy_next_30": "19 %",
            "occupancy_next_60": "2 %",
            "market_occupancy_next_60": "14 %",
            "occupancy_next_90": "1 %",
            "market_occupancy_next_90": "11 %",
            "occupancy_next_120": "8 %",
            "market_occupancy_next_120": "11 %",
            "revenue_next_120": 2152,
            "stly_revenue_next_120": 9018,
            "adr_next_120": 269,
            "stly_adr_next_120": 220,
            "recommended_base_price": "Unavailable",
            "last_refreshed_at": null
        },
        {
            "id": "1239626",
            "pms": "smartbnb",
            "name": " \u00b7 ",
            "no_of_bedrooms": 0,
            "min": null,
            "base": null,
            "max": null,
            "group": null,
            "subgroup": null,
            "tags": null,
            "notes": null,
            "isHidden": true,
            "push_enabled": false,
            "last_date_pushed": null,
            "last_booked_date": "-",
            "occupancy_next_30": null,
            "market_occupancy_next_30": "Unavailable",
            "occupancy_next_60": null,
            "market_occupancy_next_60": "Unavailable",
            "occupancy_next_90": null,
            "market_occupancy_next_90": "Unavailable",
            "occupancy_next_120": null,
            "market_occupancy_next_120": "Unavailable",
            "revenue_next_120": null,
            "stly_revenue_next_120": "Unavailable",
            "adr_next_120": null,
            "stly_adr_next_120": "Unavailable",
            "recommended_base_price": "Unavailable",
            "last_refreshed_at": null
        },
        {
            "id": "1390452",
            "pms": "smartbnb",
            "name": "450ft from Beach|King bed|Arcade",
            "no_of_bedrooms": 4,
            "min": 184,
            "base": 370,
            "max": null,
            "group": null,
            "subgroup": null,
            "tags": null,
            "notes": null,
            "isHidden": false,
            "push_enabled": true,
            "last_date_pushed": "2025-02-06T08:39:06.000Z",
            "last_booked_date": "2025-02-03T00:00:00.000Z",
            "occupancy_next_30": "7 %",
            "market_occupancy_next_30": "11 %",
            "occupancy_next_60": "3 %",
            "market_occupancy_next_60": "10 %",
            "occupancy_next_90": "2 %",
            "market_occupancy_next_90": "9 %",
            "occupancy_next_120": "3 %",
            "market_occupancy_next_120": "9 %",
            "revenue_next_120": 1436,
            "stly_revenue_next_120": "-",
            "adr_next_120": 359,
            "stly_adr_next_120": "-",
            "recommended_base_price": "Unavailable",
            "last_refreshed_at": "2025-02-06T08:39:01+00:00"
        },
        {
            "id": "1438846",
            "pms": "smartbnb",
            "name": "Lakefront| Sunset |nr Sylvan bch",
            "no_of_bedrooms": 3,
            "min": 184,
            "base": 463,
            "max": null,
            "group": null,
            "subgroup": null,
            "tags": null,
            "notes": null,
            "isHidden": false,
            "push_enabled": true,
            "last_date_pushed": "2025-02-06T08:39:04.000Z",
            "last_booked_date": "2025-02-02T00:00:00.000Z",
            "occupancy_next_30": "53 %",
            "market_occupancy_next_30": "16 %",
            "occupancy_next_60": "33 %",
            "market_occupancy_next_60": "13 %",
            "occupancy_next_90": "22 %",
            "market_occupancy_next_90": "10 %",
            "occupancy_next_120": "24 %",
            "market_occupancy_next_120": "11 %",
            "revenue_next_120": 8667,
            "stly_revenue_next_120": "-",
            "adr_next_120": 299,
            "stly_adr_next_120": "-",
            "recommended_base_price": "Unavailable",
            "last_refreshed_at": "2025-02-06T08:38:59+00:00"
        },
        {
            "id": "1460674",
            "pms": "smartbnb",
            "name": "Twin Lakefront homes, Large grp",
            "no_of_bedrooms": 5,
            "min": 400,
            "base": 650,
            "max": null,
            "group": null,
            "subgroup": null,
            "tags": null,
            "notes": null,
            "isHidden": false,
            "push_enabled": false,
            "last_date_pushed": "2025-01-19T06:11:55.000Z",
            "last_booked_date": "2024-06-11T00:00:00.000Z",
            "occupancy_next_30": "83 %",
            "market_occupancy_next_30": "15 %",
            "occupancy_next_60": "92 %",
            "market_occupancy_next_60": "13 %",
            "occupancy_next_90": "92 %",
            "market_occupancy_next_90": "11 %",
            "occupancy_next_120": "93 %",
            "market_occupancy_next_120": "11 %",
            "revenue_next_120": 0,
            "stly_revenue_next_120": "-",
            "adr_next_120": 0,
            "stly_adr_next_120": "-",
            "recommended_base_price": 634,
            "last_refreshed_at": "2025-02-06T00:05:27+00:00"
        }
    ]
}'''

# Load JSON into a Python dictionary (nulls become None)
parsed_data = json.loads(data)

# Convert JSON to DataFrame
df = pd.json_normalize(parsed_data['listings'])
df

# %%
my_dir = "listings_data/listings_Alex/listings_Alex.json"
